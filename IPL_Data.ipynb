# %%
### Load required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the IPL dataset
data = pd.read_csv('E:\SYMBIOSIS MSC DSSA\ipl_dataset.csv')
ipl= pd.DataFrame(data)
ipl
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
# Have a glance at first 10 rows of the dataset

ipl.head(10)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
# 5   6    2008      Jaipur  2008-04-21        Kings XI Punjab
# 6   7    2008   Hyderabad  2008-04-22        Deccan Chargers
# 7   8    2008     Chennai  2008-04-23    Chennai Super Kings
# 8   9    2008   Hyderabad  2008-04-24        Deccan Chargers
# 9  10    2008  Chandigarh  2008-04-25        Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# ...

# %%
# Find the number of rows and columns

print('The number of rows are ',ipl.shape[0])
print('The number of columns are ',ipl.shape[1])
# Out:
# The number of rows are  577
# The number of columns are  18

# %%
# Get the frequency of most 'Man of the Match' awards

count=ipl['player_of_match'].value_counts()
count
# Out:
# player_of_match
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
#                   ..
# MN Samuels         1
# S Badrinath        1
# R Bhatia           1
# RE Levi            1
# BCJ Cutting        1
# Name: count, Length: 187, dtype: int64

# %%
# Get Top 10 players with most man of the matches

count[:10]   # or you can also write--  ipl['player_of_match'].value_counts()[:10]
# Out:
# player_of_match
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
# SK Raina          13
# AM Rahane         12
# MEK Hussey        12
# G Gambhir         12
# MS Dhoni          12
# Name: count, dtype: int64

# %%
# Get Top 5 players with most man of the matches

ipl['player_of_match'].value_counts()[:5]
# Out:
# player_of_match
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
# Name: count, dtype: int64

# %%
# bar plot on the top 5 man of the matches and how many won

players = list(ipl['player_of_match'].value_counts()[:5].keys())
winnings = list(ipl['player_of_match'].value_counts()[:5])
plt.bar(players,winnings,color='orange',edgecolor='k')
plt.xlabel('Player Names')
plt.ylabel('Number of Man of the Match Titles won')
plt.title('MAN OF THE MATCHES')
plt.show()

# %%
# count the result column

ipl['result'].value_counts()
# Out:
# result
# normal       568
# tie            6
# no result      3
# Name: count, dtype: int64

# %%
# find the number of toss wins with respect to each team

ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 74
# Kolkata Knight Riders          69
# Chennai Super Kings            66
# Kings XI Punjab                64
# Delhi Daredevils               64
# Rajasthan Royals               63
# Royal Challengers Bangalore    61
# Deccan Chargers                43
# Sunrisers Hyderabad            30
# Pune Warriors                  20
# Kochi Tuskers Kerala            8
# Gujarat Lions                   8
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
# extract records where a team won by batting first

winner_batting_first = ipl[ipl['win_by_runs'] != 0]
winner_batting_first
# Out:
#       id  season           city        date                        team1  \
# 0      1    2008      Bangalore  2008-04-18        Kolkata Knight Riders
# 1      2    2008     Chandigarh  2008-04-19          Chennai Super Kings
# 7      8    2008        Chennai  2008-04-23          Chennai Super Kings
# 9     10    2008     Chandigarh  2008-04-25              Kings XI Punjab
# 14    15    2008      Bangalore  2008-04-28          Chennai Super Kings
# ..   ...     ...            ...         ...                          ...
# 565  566    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 566  567    2016      Bangalore  2016-05-18  Royal Challengers Bangalore
# 571  572    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 574  575    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 576  577    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# to determine margin of runs while winning of the teams

plt.hist(winner_batting_first['win_by_runs'],color='magenta',edgecolor='k')
plt.xlabel('Runs')
plt.title('Distribution of Runs')
plt.grid(True)
plt.show()

# %%
# finding out the number of wins w.r.t each team after batting first

first_batting = ipl[ipl['win_by_runs'] != 0]
first_batting['winner'].value_counts()
# Out:
# winner
# Chennai Super Kings            46
# Mumbai Indians                 43
# Kolkata Knight Riders          29
# Kings XI Punjab                28
# Royal Challengers Bangalore    27
# Rajasthan Royals               23
# Delhi Daredevils               18
# Deccan Chargers                18
# Sunrisers Hyderabad            18
# Pune Warriors                   6
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: count, dtype: int64

# %%
# plotting a bar plot for top 3 teams with most wins after batting first

top_3 = first_batting['winner'].value_counts().head(3)
plt.bar(top_3.keys(), top_3, color = ['r','b','g'], edgecolor = 'k')
plt.xlabel('Teams')
plt.ylabel('Number of Wins')
plt.title('Top 3 Teams with Most Wins')
plt.show()

# %%
# making a pie_chart

plt.figure(figsize = (7,7))
labels = list(first_batting['winner'].value_counts().keys())
plt.pie(list(first_batting['winner'].value_counts()), labels = labels , autopct = '%0.2f%%')
plt.show()

# %%
# looking at the number of matches played each season

ipl['season'].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
# looking at the number of matches played in each city

ipl['city'].value_counts()
# Out:
# city
# Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Port Elizabeth     7
# Cape Town          7
# Ranchi             7
# Abu Dhabi          7
# Sharjah            6
# Raipur             6
# Kochi              5
# Rajkot             5
# Kimberley          3
# Nagpur             3
# East London        3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: count, dtype: int64

# %%
# finding out records where a team won the match after batting second

batting_second = ipl[ipl['win_by_wickets'] != 0]
batting_second
# Out:
#       id  season           city        date             team1  \
# 2      3    2008          Delhi  2008-04-19  Rajasthan Royals
# 3      4    2008         Mumbai  2008-04-20    Mumbai Indians
# 4      5    2008        Kolkata  2008-04-20   Deccan Chargers
# 5      6    2008         Jaipur  2008-04-21   Kings XI Punjab
# 6      7    2008      Hyderabad  2008-04-22   Deccan Chargers
# ..   ...     ...            ...         ...               ...
# 569  570    2016  Visakhapatnam  2016-05-21   Kings XI Punjab
# 570  571    2016         Kanpur  2016-05-21    Mumbai Indians
# 572  573    2016         Raipur  2016-05-22  Delhi Daredevils
# 573  574    2016      Bangalore  2016-05-24     Gujarat Lions
# 575  576    2016          Delhi  2016-05-27     Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# 2               Delhi Daredevils             Rajasthan Royals           bat
# ...

# %%
# extract records where team won both the toss and the match

first_batting_won = ipl[ipl['winner'] == ipl['toss_winner']]
first_batting_won
# Out:
#       id  season        city        date                        team1  \
# 1      2    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 8      9    2008   Hyderabad  2008-04-24              Deccan Chargers
# 10    11    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 12    13    2008      Mumbai  2008-04-27               Mumbai Indians
# 14    15    2008   Bangalore  2008-04-28          Chennai Super Kings
# ..   ...     ...         ...         ...                          ...
# 570  571    2016      Kanpur  2016-05-21               Mumbai Indians
# 572  573    2016      Raipur  2016-05-22             Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24                Gujarat Lions
# 575  576    2016       Delhi  2016-05-27                Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# plot a histogram to show number of wins w.r.t number of wickets

plt.hist(batting_second['win_by_wickets'],edgecolor = 'k',color='g')
plt.xlabel('Number of Wickets')
plt.ylabel('Number of Wins')
plt.title('Number of wins w.r.t number of wickets')
plt.show()

# %%
# frequency of number of wins after batting second

second_batting = ipl[ipl['win_by_wickets'] != 0]
second_batting_wins = second_batting['winner']
second_batting_wins.value_counts()
# Out:
# winner
# Royal Challengers Bangalore    42
# Kolkata Knight Riders          39
# Delhi Daredevils               38
# Rajasthan Royals               38
# Mumbai Indians                 37
# Chennai Super Kings            33
# Kings XI Punjab                33
# Sunrisers Hyderabad            15
# Deccan Chargers                11
# Gujarat Lions                   8
# Pune Warriors                   6
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: count, dtype: int64

# %%
# finding out how many times a team won match after winning toss

toss_and_match_win = ipl[ipl['toss_winner'] == ipl['winner']]
toss_and_match_win['winner'].value_counts()
# Out:
# winner
# Chennai Super Kings            42
# Mumbai Indians                 41
# Kolkata Knight Riders          38
# Rajasthan Royals               34
# Royal Challengers Bangalore    33
# Delhi Daredevils               28
# Kings XI Punjab                26
# Deccan Chargers                19
# Sunrisers Hyderabad            14
# Gujarat Lions                   6
# Kochi Tuskers Kerala            4
# Pune Warriors                   3
# Rising Pune Supergiants         3
# Name: count, dtype: int64

# %%
sum = np.sum(ipl['toss_winner'] == ipl['winner'])
print('The number of times a team won match after winning toss is',sum)
print('The total number of matches played is 577')
# Out:
# The number of times a team won match after winning toss is 291
# The total number of matches played is 577
